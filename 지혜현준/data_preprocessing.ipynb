# %%
import pandas as pd

# %%
# Read the Excel file into a DataFrame
file_path = 'data/CB Insights AI 100 2024.xlsx'
excel_file = pd.ExcelFile(file_path)
excel_file.sheet_names
# Out:
# ['2024 AI 100', 'Fintech Collection data', 'Fintech - all companies data']

# %%
# Load the main sheet which appears to be '2024 AI 100'
df = pd.read_excel(file_path, sheet_name='2024 AI 100')

# Display the first few rows to identify any header or extra explanation rows
df.head(10)
# Out:
#    Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN  The most promising artificial intelligence sta...         NaN
# 3         NaN                             (data as of 3/25/2024)         NaN
# 4         NaN                                                NaN         NaN
# 5         NaN                                       Company Name         NaN
# 6         NaN                                                NaN         NaN
# 7         NaN                                                NaN         NaN
# 8         NaN                                              01.AI         NaN
# 9         NaN                                                 1X         NaN
#
#                                    Unnamed: 3  Unnamed: 4         Unnamed: 5  \
# ...

# %%
# Use the actual header row (row 5) to set column names and filter the data accordingly
df.columns = df.iloc[5]
df = df[8:]  # Start from actual data rows (row 8 based on preview)

# Clean up the DataFrame by resetting the index and dropping any unnecessary columns
df.reset_index(drop=True, inplace=True)

# %%
df.head(10)
# Out:
# 5  NaN       Company Name  NaN                           CB Insights Profile  \
# 0  NaN              01.AI  NaN       www.cbinsights.com/company/lingyi-wanwu
# 1  NaN                 1X  NaN    www.cbinsights.com/company/halodi-robotics
# 2  NaN        Adaptive ML  NaN        www.cbinsights.com/company/adaptive-ml
# 3  NaN              Adept  NaN            www.cbinsights.com/company/adept-3
# 4  NaN            Aionics  NaN            www.cbinsights.com/company/aionics
# 5  NaN          Anthropic  NaN          www.cbinsights.com/company/anthropic
# 6  NaN            Argilla  NaN           www.cbinsights.com/company/recognai
# 7  NaN  Atomic Industries  NaN  www.cbinsights.com/company/atomic-industries
# 8  NaN        Atypical AI  NaN        www.cbinsights.com/company/atypical-ai
# 9  NaN            Binarly  NaN            www.cbinsights.com/company/binarly
#
# 5  NaN           Category  NaN                            Product focus  NaN  \
# ...

# %%
# Drop columns with all NaN values
df = df.dropna(axis=1, how='all')

# Display the updated DataFrame
df.head()
# Out:
# 5 Company Name                         CB Insights Profile           Category  \
# 0        01.AI     www.cbinsights.com/company/lingyi-wanwu  AI infrastructure
# 1           1X  www.cbinsights.com/company/halodi-robotics      Horizontal AI
# 2  Adaptive ML      www.cbinsights.com/company/adaptive-ml  AI infrastructure
# 3        Adept          www.cbinsights.com/company/adept-3      Horizontal AI
# 4      Aionics          www.cbinsights.com/company/aionics        Vertical AI
#
# 5                       Product focus        Country  \
# 0            Models - Open foundation          China
# 1                           Humanoids         Norway
# 2  AI development platforms - Unified  United States
# 3                   Enterprise agents  United States
# 4                              Energy  United States
#
# 5                                          Investors  \
# 0                 Sinovation Ventures, Alibaba Cloud
# 1  Type One Ventures, ADT Security Services, Vali...
# ...

# %%
# Check for rows where the "Latest Funding Round" is Seed VC or Pre-seed
filtered_df = df[
    df["Latest Funding Round"].str.lower().isin(["seed vc", "pre-seed", "incubator", "convertible note", "grant"])
]

# %%
filtered_df.head(10)
# Out:
# 5            Company Name                               CB Insights Profile  \
# 2             Adaptive ML            www.cbinsights.com/company/adaptive-ml
# 4                 Aionics                www.cbinsights.com/company/aionics
# 7       Atomic Industries      www.cbinsights.com/company/atomic-industries
# 8             Atypical AI            www.cbinsights.com/company/atypical-ai
# 9                 Binarly                www.cbinsights.com/company/binarly
# 10              Bioptimus              www.cbinsights.com/company/bioptimus
# 12                  Chalk               www.cbinsights.com/company/chalk-ai
# 14               Cleanlab               www.cbinsights.com/company/cleanlab
# 16  Common Sense Machines  www.cbinsights.com/company/common-sense-machines
# 20             DatologyAI             www.cbinsights.com/company/datologyai
#
# 5            Category                       Product focus        Country  \
# ...

# %%
filtered_df.reset_index(drop=True, inplace=True)
filtered_df.to_csv('angel_filtered_data.csv', index=False, header=True)
